# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import gensim.downloader as api

# %%
model = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# Removed accidental overwrite of model

# %%
length = len(model)

# %%
model.most_similar("Deepak")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model.most_similar("Deepak")
#
# AttributeError: 'list' object has no attribute 'most_similar'

# %%
model.similarity("man","women")

# %%
model.doesnt_match(["breakfast","lunch","dinner","car"])

# %%
vect=model["king"]-model["man"]+model["woman"]

# %%
model.most_similar("vect")

# %% [markdown]
# ##convert sentense to vector using word to vec techinique

# %%
sentence="I love machine learning"

# %%
words=sentence.lower().split()

# %%
word_vector
