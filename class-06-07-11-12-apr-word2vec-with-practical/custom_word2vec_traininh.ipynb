# %%
import pandas as pd
import numpy as np
import os
import gensim
import nltk

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
for file in os.listdir('./Data/'):
    print(file)
# Out:
# story1.txt
# story2.txt

# %%
f = open(r"C:\Users\deepa\Downloads\test_dummy\class-06-07-11-12-apr-word2vec-with-practical\Data\story1.txt",encoding='unicode_escape')

# %%
f
# Out:
# <_io.TextIOWrapper name='C:\\Users\\deepa\\Downloads\\test_dummy\\class-06-07-11-12-apr-word2vec-with-practical\\Data\\story1.txt' mode='r' encoding='unicode_escape'>

# %%
corpus =f.read()

# %%
corpus
# Out:
# 'Once upon a time, there was a young boy named Arjun who lived in a small town surrounded by hills and rivers. He was very curious about how things worked and always asked questions. His parents often smiled at his curiosity and encouraged him to learn more.\n\nEvery day after school, Arjun would sit with his books and explore different topics. He was especially fascinated by science and technology. He wanted to understand how machines think and whether they could become as intelligent as humans.\n\nOne day, while browsing through an old computer at school, Arjun discovered the concept of artificial intelligence. He read about how machines can learn from data, recognize patterns, and even make decisions. This idea completely amazed him.\n\nHe started imagining a future where machines could help humans solve complex problems. That day, he made a decision that he wanted to become an AI engineer.\n\nArjun began learning programming using free resources. At first, everything seemed diffi
# ...

# %%
sent_tokenize(corpus)
# Out:
# ['Once upon a time, there was a young boy named Arjun who lived in a small town surrounded by hills and rivers.',
#  'He was very curious about how things worked and always asked questions.',
#  'His parents often smiled at his curiosity and encouraged him to learn more.',
#  'Every day after school, Arjun would sit with his books and explore different topics.',
#  'He was especially fascinated by science and technology.',
#  'He wanted to understand how machines think and whether they could become as intelligent as humans.',
#  'One day, while browsing through an old computer at school, Arjun discovered the concept of artificial intelligence.',
#  'He read about how machines can learn from data, recognize patterns, and even make decisions.',
#  'This idea completely amazed him.',
#  'He started imagining a future where machines could help humans solve complex problems.',
#  'That day, he made a decision that he wanted to become an AI engineer.',
# ...

# %%
raw_sent = sent_tokenize(corpus)

# %%
for i in raw_sent:
  print(simple_preprocess(i))
# Out:
# ['once', 'upon', 'time', 'there', 'was', 'young', 'boy', 'named', 'arjun', 'who', 'lived', 'in', 'small', 'town', 'surrounded', 'by', 'hills', 'and', 'rivers']
# ['he', 'was', 'very', 'curious', 'about', 'how', 'things', 'worked', 'and', 'always', 'asked', 'questions']
# ['his', 'parents', 'often', 'smiled', 'at', 'his', 'curiosity', 'and', 'encouraged', 'him', 'to', 'learn', 'more']
# ['every', 'day', 'after', 'school', 'arjun', 'would', 'sit', 'with', 'his', 'books', 'and', 'explore', 'different', 'topics']
# ['he', 'was', 'especially', 'fascinated', 'by', 'science', 'and', 'technology']
# ['he', 'wanted', 'to', 'understand', 'how', 'machines', 'think', 'and', 'whether', 'they', 'could', 'become', 'as', 'intelligent', 'as', 'humans']
# ['one', 'day', 'while', 'browsing', 'through', 'an', 'old', 'computer', 'at', 'school', 'arjun', 'discovered', 'the', 'concept', 'of', 'artificial', 'intelligence']
# ...

# %%
folder_path = r"C:\Users\deepa\Downloads\test_dummy\class-06-07-11-12-apr-word2vec-with-practical\Data"
story = []
for filename in os.listdir(folder_path):
  file_path=os.path.join(folder_path,filename)
  with open(file_path,encoding='unicode_escape') as f:
    corpus=f.read()
  raw_sent=sent_tokenize(corpus)
  for sent in raw_sent:
    story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['once',
#   'upon',
#   'time',
#   'there',
#   'was',
#   'young',
#   'boy',
#   'named',
#   'arjun',
#   'who',
#   'lived',
#   'in',
#   'small',
#   'town',
#   'surrounded',
#   'by',
#   'hills',
#   'and',
#   'rivers'],
#  ['he',
#   'was',
#   'very',
#   'curious',
#   'about',
#   'how',
#   'things',
#   'worked',
#   'and',
#   'always',
#   'asked',
#   'questions'],
#  ['his',
#   'parents',
#   'often',
#   'smiled',
#   'at',
#   'his',
#   'curiosity',
#   'and',
#   'encouraged',
#   'him',
#   'to',
#   'learn',
#   'more'],
#  ['every',
#   'day',
#   'after',
#   'school',
#   'arjun',
#   'would',
#   'sit',
#   'with',
#   'his',
#   'books',
#   'and',
#   'explore',
#   'different',
#   'topics'],
#  ['he',
#   'was',
#   'especially',
#   'fascinated',
#   'by',
#   'science',
#   'and',
#   'technology'],
#  ['he',
#   'wanted',
#   'to',
#   'understand',
#   'how',
#   'machines',
#   'think',
#   'and',
#   'whether',
#   'they',
#   'could',
# ...

# %%
story[0]
# Out:
# ['once',
#  'upon',
#  'time',
#  'there',
#  'was',
#  'young',
#  'boy',
#  'named',
#  'arjun',
#  'who',
#  'lived',
#  'in',
#  'small',
#  'town',
#  'surrounded',
#  'by',
#  'hills',
#  'and',
#  'rivers']

# %%
story[1]
# Out:
# ['he',
#  'was',
#  'very',
#  'curious',
#  'about',
#  'how',
#  'things',
#  'worked',
#  'and',
#  'always',
#  'asked',
#  'questions']

# %% [markdown]
# sunny->100
# Divyansh->6
# Rahul->3

# %% [markdown]
# # Word2Vec(..., sg=0)  # CBOW #by default
# # Word2Vec(..., sg=1)  # Skip-gram

# %%
custom_model =gensim.models.Word2Vec(
    window=10,
    min_count=1,
    vector_size=150
    
)

## these all the value are the hyperparameter

# %%
custom_model.build_vocab(story)

# %%
custom_model.corpus_count
# Out:
# 44

# %%
custom_model.train(story, total_examples=custom_model.corpus_count, epochs=10)
# Out:
# (3392, 5220)

# %%
len(custom_model.wv["arjun"])
# Out:
# 150

# %%
custom_model.wv['farmers']
# Out:
# array([ 2.23730737e-03, -5.31128515e-03,  5.89679554e-03, -3.37118073e-03,
#        -4.18268004e-03, -8.63772410e-04,  3.01115448e-03,  1.22340361e-03,
#         2.09979434e-03,  7.39734061e-03, -2.35537626e-03,  6.01808913e-03,
#        -3.39591032e-04,  3.44345276e-03,  4.25820285e-03,  1.35079911e-03,
#         6.49258913e-03, -5.83180180e-03, -9.51745198e-04,  4.35618171e-03,
#         5.59208030e-03,  3.73755535e-03,  1.07148464e-03,  3.60621052e-04,
#         5.62083535e-03,  2.11066660e-03,  2.67408579e-03, -5.18255914e-03,
#        -6.31511270e-04, -6.27825549e-03, -5.93557925e-05, -5.72558912e-03,
#        -1.79470994e-03,  6.06062170e-03, -5.96442074e-03,  5.89011796e-03,
#        -3.19564273e-03,  4.67501674e-03,  2.78325519e-03, -5.16371988e-03,
#        -4.73139156e-03, -3.75257712e-03, -6.45174319e-03, -3.97009170e-03,
#         1.20869523e-03, -5.70503809e-03, -6.92597777e-03,  4.59920662e-03,
# ...

# %%
custom_model.wv.most_similar("arjun")
# Out:
# [('be', 0.3054593503475189),
#  ('slowly', 0.2849609851837158),
#  ('most', 0.27533233165740967),
#  ('lack', 0.27331820130348206),
#  ('patterns', 0.2507514953613281),
#  ('whenever', 0.24413524568080902),
#  ('him', 0.235578253865242),
#  ('so', 0.23494984209537506),
#  ('teachers', 0.23073934018611908),
#  ('on', 0.22639144957065582)]

# %%
custom_model.wv.most_similar("data")
# Out:
# [('struggling', 0.28323623538017273),
#  ('engineer', 0.27329108119010925),
#  ('realized', 0.2722215950489044),
#  ('boy', 0.217498779296875),
#  ('and', 0.19319544732570648),
#  ('kept', 0.17781716585159302),
#  ('think', 0.17550215125083923),
#  ('he', 0.17119476199150085),
#  ('of', 0.1692706197500229),
#  ('more', 0.16912411153316498)]

# %%
custom_model.wv.doesnt_match(["arjun","programming","farmer","engineer"])
# Out:
# 'arjun'

# %%
custom_model.wv.doesnt_match(["data","programming","farmer","engineer"])
# Out:
# 'programming'

# %%
custom_model.wv.similarity("ai","data")
# Out:
# np.float32(0.12811068)

# %%
custom_model.wv.similarity("ai","technology")
# Out:
# np.float32(0.08006859)

# %%
custom_model.wv.similarity("data","technology")
# Out:
# np.float32(0.0661789)
