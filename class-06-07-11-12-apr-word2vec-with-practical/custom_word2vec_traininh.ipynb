# %%
import pandas as pd
import numpy as np
import os
import gensim
import nltk

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
for file in os.listdir('./Data/'):
    print(file)
# Out:
# story1.txt
# story2.txt

# %%
from pathlib import Path

file_path = Path.cwd() / 'class-06-07-11-12-apr-word2vec-with-practical' / 'Data' / 'story1.txt'
print(file_path)
with open(file_path, encoding='utf-8') as f:
    text = f.read()

print(text[:200])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 f = open(r"D:\class-06-07-11-12-apr-word2vec-with-practical\Data\story1.txt",encoding='unicode_escape')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\class-06-07-11-12-apr-word2vec-with-practical\\Data\\story1.txt'

# %%
f
